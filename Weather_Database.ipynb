# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the API key.
from config import weather_api_key

# Import the requests library.
import requests

# Import time module
import time

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 764

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    print(city_url)
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_data_all=requests.get(city_url)
        city_weather = city_data_all.json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0].get("description")
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "City_Description": city_description})
    # If an error is experienced, skip the city.
    except :
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=salta
# Processing Record 1 of Set 1 | salta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=cherskiy
# Processing Record 2 of Set 1 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=namibe
# Processing Record 3 of Set 1 | namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=rikitea
# Processing Record 4 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=barrow
# Processing Record 5 of Set 1 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=ushuaia
# Processing Record 6 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=butaritari
# Processing Record 7 of Set 1 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=bati
# Processing Record 8 of Set 1 | bati
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=cidreira
# Processing Record 9 of Set 1 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=pareora
# Processing Record 10 of Set 1 | pareora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=gorin
# Processing Record 11 of Set 1 | gorin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=poum
# Processing Record 12 of Set 1 | poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=barentsburg
# Processing Record 13 of Set 1 | barentsburg
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=kumano
# Processing Record 14 of Set 1 | kumano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=mys+shmidta
# Processing Record 15 of Set 1 | mys shmidta
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=broome
# Processing Record 16 of Set 1 | broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=ostrovnoy
# Processing Record 17 of Set 1 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=jinchang
# Processing Record 18 of Set 1 | jinchang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=qaanaaq
# Processing Record 19 of Set 1 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=atuona
# Processing Record 20 of Set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=pangnirtung
# Processing Record 21 of Set 1 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=mahebourg
# Processing Record 22 of Set 1 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=havelock
# Processing Record 23 of Set 1 | havelock
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=busselton
# Processing Record 24 of Set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=kapaa
# Processing Record 25 of Set 1 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=mount+gambier
# Processing Record 26 of Set 1 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=ozgon
# Processing Record 27 of Set 1 | ozgon
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=nome
# Processing Record 28 of Set 1 | nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=aswan
# Processing Record 29 of Set 1 | aswan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=kaeo
# Processing Record 30 of Set 1 | kaeo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=hermanus
# Processing Record 31 of Set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=kavaratti
# Processing Record 32 of Set 1 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=andenes
# Processing Record 33 of Set 1 | andenes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=vaini
# Processing Record 34 of Set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=avarua
# Processing Record 35 of Set 1 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=victor+harbor
# Processing Record 36 of Set 1 | victor harbor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=mataura
# Processing Record 37 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=paragominas
# Processing Record 38 of Set 1 | paragominas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=albany
# Processing Record 39 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=foumban
# Processing Record 40 of Set 1 | foumban
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=sobolevo
# Processing Record 41 of Set 1 | sobolevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=kismayo
# Processing Record 42 of Set 1 | kismayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=cayenne
# Processing Record 43 of Set 1 | cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=leh
# Processing Record 44 of Set 1 | leh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=port+alfred
# Processing Record 45 of Set 1 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=punta+arenas
# Processing Record 46 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=yellowknife
# Processing Record 47 of Set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=alice+springs
# Processing Record 48 of Set 1 | alice springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=aliwal+north
# Processing Record 49 of Set 1 | aliwal north
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=killybegs
# Processing Record 50 of Set 1 | killybegs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=saquarema
# Processing Record 1 of Set 2 | saquarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=tasiilaq
# Processing Record 2 of Set 2 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=dolbeau
# Processing Record 3 of Set 2 | dolbeau
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=vestmannaeyjar
# Processing Record 4 of Set 2 | vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=mount+isa
# Processing Record 5 of Set 2 | mount isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=calvinia
# Processing Record 6 of Set 2 | calvinia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=bengkulu
# Processing Record 7 of Set 2 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=mbandaka
# Processing Record 8 of Set 2 | mbandaka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=bubaque
# Processing Record 9 of Set 2 | bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=nagorsk
# Processing Record 10 of Set 2 | nagorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=yeletskiy
# Processing Record 11 of Set 2 | yeletskiy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=saint-philippe
# Processing Record 12 of Set 2 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=lundazi
# Processing Record 13 of Set 2 | lundazi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=sisimiut
# Processing Record 14 of Set 2 | sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=bredasdorp
# Processing Record 15 of Set 2 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=husavik
# Processing Record 16 of Set 2 | husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=orel-izumrud
# Processing Record 17 of Set 2 | orel-izumrud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=esperance
# Processing Record 18 of Set 2 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=tuktoyaktuk
# Processing Record 19 of Set 2 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=karabash
# Processing Record 20 of Set 2 | karabash
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=georgetown
# Processing Record 21 of Set 2 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=cape+town
# Processing Record 22 of Set 2 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=novikovo
# Processing Record 23 of Set 2 | novikovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=ransang
# Processing Record 24 of Set 2 | ransang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=tabas
# Processing Record 25 of Set 2 | tabas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=bluff
# Processing Record 26 of Set 2 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=banff
# Processing Record 27 of Set 2 | banff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=tsihombe
# Processing Record 28 of Set 2 | tsihombe
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=ribeira+grande
# Processing Record 29 of Set 2 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=east+london
# Processing Record 30 of Set 2 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=souillac
# Processing Record 31 of Set 2 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=truth+or+consequences
# Processing Record 32 of Set 2 | truth or consequences
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=beringovskiy
# Processing Record 33 of Set 2 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=klaksvik
# Processing Record 34 of Set 2 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=arraial+do+cabo
# Processing Record 35 of Set 2 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=bethel
# Processing Record 36 of Set 2 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=hilo
# Processing Record 37 of Set 2 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=belushya+guba
# Processing Record 38 of Set 2 | belushya guba
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=lompoc
# Processing Record 39 of Set 2 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=isangel
# Processing Record 40 of Set 2 | isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=geraldton
# Processing Record 41 of Set 2 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=governador+valadares
# Processing Record 42 of Set 2 | governador valadares
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=umm+lajj
# Processing Record 43 of Set 2 | umm lajj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=homer
# Processing Record 44 of Set 2 | homer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=fallon
# Processing Record 45 of Set 2 | fallon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=vao
# Processing Record 46 of Set 2 | vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=victoria
# Processing Record 47 of Set 2 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=aklavik
# Processing Record 48 of Set 2 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=coahuayana
# Processing Record 49 of Set 2 | coahuayana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=mayor+pablo+lagerenza
# Processing Record 50 of Set 2 | mayor pablo lagerenza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=barra+do+garcas
# Processing Record 1 of Set 3 | barra do garcas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=faanui
# Processing Record 2 of Set 3 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=barra+da+estiva
# Processing Record 3 of Set 3 | barra da estiva
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=cockburn+harbour
# Processing Record 4 of Set 3 | cockburn harbour
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=tucupita
# Processing Record 5 of Set 3 | tucupita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=kodiak
# Processing Record 6 of Set 3 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=amderma
# Processing Record 7 of Set 3 | amderma
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=port+elizabeth
# Processing Record 8 of Set 3 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=kavieng
# Processing Record 9 of Set 3 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=lidkoping
# Processing Record 10 of Set 3 | lidkoping
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=kamsack
# Processing Record 11 of Set 3 | kamsack
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=khatanga
# Processing Record 12 of Set 3 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=labutta
# Processing Record 13 of Set 3 | labutta
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=mnogovershinnyy
# Processing Record 14 of Set 3 | mnogovershinnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=homestead
# Processing Record 15 of Set 3 | homestead
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=garden+city
# Processing Record 16 of Set 3 | garden city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=hasaki
# Processing Record 17 of Set 3 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=faya
# Processing Record 18 of Set 3 | faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=aden
# Processing Record 19 of Set 3 | aden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=oranjemund
# Processing Record 20 of Set 3 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=meulaboh
# Processing Record 21 of Set 3 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=usman
# Processing Record 22 of Set 3 | usman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=ust-kulom
# Processing Record 23 of Set 3 | ust-kulom
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=bhainsdehi
# Processing Record 24 of Set 3 | bhainsdehi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=nanortalik
# Processing Record 25 of Set 3 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=new+norfolk
# Processing Record 26 of Set 3 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=sao+jose+dos+campos
# Processing Record 27 of Set 3 | sao jose dos campos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=padang
# Processing Record 28 of Set 3 | padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=katsuura
# Processing Record 29 of Set 3 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=nongan
# Processing Record 30 of Set 3 | nongan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=canico
# Processing Record 31 of Set 3 | canico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=marawi
# Processing Record 32 of Set 3 | marawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=burns+lake
# Processing Record 33 of Set 3 | burns lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=upernavik
# Processing Record 34 of Set 3 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=saldanha
# Processing Record 35 of Set 3 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=kamina
# Processing Record 36 of Set 3 | kamina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=illoqqortoormiut
# Processing Record 37 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=baykit
# Processing Record 38 of Set 3 | baykit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=naze
# Processing Record 39 of Set 3 | naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=lebu
# Processing Record 40 of Set 3 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=uyuni
# Processing Record 41 of Set 3 | uyuni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=castro
# Processing Record 42 of Set 3 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=nyrob
# Processing Record 43 of Set 3 | nyrob
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=ukiah
# Processing Record 44 of Set 3 | ukiah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=aguas+formosas
# Processing Record 45 of Set 3 | aguas formosas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=saint+george
# Processing Record 46 of Set 3 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=filadelfia
# Processing Record 47 of Set 3 | filadelfia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=akdepe
# Processing Record 48 of Set 3 | akdepe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=salalah
# Processing Record 49 of Set 3 | salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=gizo
# Processing Record 50 of Set 3 | gizo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=dikson
# Processing Record 1 of Set 4 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=dunedin
# Processing Record 2 of Set 4 | dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=pisco
# Processing Record 3 of Set 4 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=jamestown
# Processing Record 4 of Set 4 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=unai
# Processing Record 5 of Set 4 | unai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=iqaluit
# Processing Record 6 of Set 4 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=saskylakh
# Processing Record 7 of Set 4 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=svetlyy
# Processing Record 8 of Set 4 | svetlyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=nicoya
# Processing Record 9 of Set 4 | nicoya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=hirado
# Processing Record 10 of Set 4 | hirado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=evensk
# Processing Record 11 of Set 4 | evensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=puerto+ayora
# Processing Record 12 of Set 4 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=olafsvik
# Processing Record 13 of Set 4 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=palana
# Processing Record 14 of Set 4 | palana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=talnakh
# Processing Record 15 of Set 4 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=guarapari
# Processing Record 16 of Set 4 | guarapari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=burkhala
# Processing Record 17 of Set 4 | burkhala
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=bereda
# Processing Record 18 of Set 4 | bereda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=hobart
# Processing Record 19 of Set 4 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=manzil+salim
# Processing Record 20 of Set 4 | manzil salim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=tupik
# Processing Record 21 of Set 4 | tupik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=mawlaik
# Processing Record 22 of Set 4 | mawlaik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=nizhneyansk
# Processing Record 23 of Set 4 | nizhneyansk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=severo-kurilsk
# Processing Record 24 of Set 4 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=mar+del+plata
# Processing Record 25 of Set 4 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=langfang
# Processing Record 26 of Set 4 | langfang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=nikolskoye
# Processing Record 27 of Set 4 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=taolanaro
# Processing Record 28 of Set 4 | taolanaro
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=san+pedro
# Processing Record 29 of Set 4 | san pedro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=garbolovo
# Processing Record 30 of Set 4 | garbolovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=zlobin
# Processing Record 31 of Set 4 | zlobin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=batsfjord
# Processing Record 32 of Set 4 | batsfjord
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=broken+hill
# Processing Record 33 of Set 4 | broken hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=ponta+do+sol
# Processing Record 34 of Set 4 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=namatanai
# Processing Record 35 of Set 4 | namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=kambove
# Processing Record 36 of Set 4 | kambove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=chumikan
# Processing Record 37 of Set 4 | chumikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=itarema
# Processing Record 38 of Set 4 | itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=banda+aceh
# Processing Record 39 of Set 4 | banda aceh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=vila
# Processing Record 40 of Set 4 | vila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=inhambane
# Processing Record 41 of Set 4 | inhambane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=lata
# Processing Record 42 of Set 4 | lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=nasturelu
# Processing Record 43 of Set 4 | nasturelu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=virginia+beach
# Processing Record 44 of Set 4 | virginia beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=shenjiamen
# Processing Record 45 of Set 4 | shenjiamen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=sosnovo-ozerskoye
# Processing Record 46 of Set 4 | sosnovo-ozerskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=aktau
# Processing Record 47 of Set 4 | aktau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=los+llanos+de+aridane
# Processing Record 48 of Set 4 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=yarada
# Processing Record 49 of Set 4 | yarada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=palabuhanratu
# Processing Record 50 of Set 4 | palabuhanratu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=benguela
# Processing Record 1 of Set 5 | benguela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=anloga
# Processing Record 2 of Set 5 | anloga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=necochea
# Processing Record 3 of Set 5 | necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=longyearbyen
# Processing Record 4 of Set 5 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=saint+anthony
# Processing Record 5 of Set 5 | saint anthony
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=bayir
# Processing Record 6 of Set 5 | bayir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=amahai
# Processing Record 7 of Set 5 | amahai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=chuy
# Processing Record 8 of Set 5 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=bealanana
# Processing Record 9 of Set 5 | bealanana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=yulara
# Processing Record 10 of Set 5 | yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=catalina
# Processing Record 11 of Set 5 | catalina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=strezhevoy
# Processing Record 12 of Set 5 | strezhevoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=sibolga
# Processing Record 13 of Set 5 | sibolga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=comodoro+rivadavia
# Processing Record 14 of Set 5 | comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=rungata
# Processing Record 15 of Set 5 | rungata
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=san+carlos+de+bariloche
# Processing Record 16 of Set 5 | san carlos de bariloche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=hithadhoo
# Processing Record 17 of Set 5 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=kaliganj
# Processing Record 18 of Set 5 | kaliganj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=chokurdakh
# Processing Record 19 of Set 5 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=laurens
# Processing Record 20 of Set 5 | laurens
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=okha
# Processing Record 21 of Set 5 | okha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=puqi
# Processing Record 22 of Set 5 | puqi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=carnarvon
# Processing Record 23 of Set 5 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=egvekinot
# Processing Record 24 of Set 5 | egvekinot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=santa+barbara
# Processing Record 25 of Set 5 | santa barbara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=sharjah
# Processing Record 26 of Set 5 | sharjah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=bloomington
# Processing Record 27 of Set 5 | bloomington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=kampen
# Processing Record 28 of Set 5 | kampen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=high+level
# Processing Record 29 of Set 5 | high level
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=san+luis
# Processing Record 30 of Set 5 | san luis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=kjollefjord
# Processing Record 31 of Set 5 | kjollefjord
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=bonavista
# Processing Record 32 of Set 5 | bonavista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=fukue
# Processing Record 33 of Set 5 | fukue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=nanning
# Processing Record 34 of Set 5 | nanning
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=petatlan
# Processing Record 35 of Set 5 | petatlan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=harper
# Processing Record 36 of Set 5 | harper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=vangaindrano
# Processing Record 37 of Set 5 | vangaindrano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=sioux+lookout
# Processing Record 38 of Set 5 | sioux lookout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=flinders
# Processing Record 39 of Set 5 | flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=barahona
# Processing Record 40 of Set 5 | barahona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=ketchikan
# Processing Record 41 of Set 5 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=vaitupu
# Processing Record 42 of Set 5 | vaitupu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=deputatskiy
# Processing Record 43 of Set 5 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=hirara
# Processing Record 44 of Set 5 | hirara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=saleaula
# Processing Record 45 of Set 5 | saleaula
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=fairbanks
# Processing Record 46 of Set 5 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=hofn
# Processing Record 47 of Set 5 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=norman+wells
# Processing Record 48 of Set 5 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=san+patricio
# Processing Record 49 of Set 5 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=dawei
# Processing Record 50 of Set 5 | dawei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=vestbygda
# Processing Record 1 of Set 6 | vestbygda
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=galiwinku
# Processing Record 2 of Set 6 | galiwinku
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=yagodnoye
# Processing Record 3 of Set 6 | yagodnoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=airai
# Processing Record 4 of Set 6 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=las+cruces
# Processing Record 5 of Set 6 | las cruces
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=clyde+river
# Processing Record 6 of Set 6 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=kangaatsiaq
# Processing Record 7 of Set 6 | kangaatsiaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=haines+junction
# Processing Record 8 of Set 6 | haines junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=sitka
# Processing Record 9 of Set 6 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=asau
# Processing Record 10 of Set 6 | asau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=kaitangata
# Processing Record 11 of Set 6 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=yerbogachen
# Processing Record 12 of Set 6 | yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=port+lincoln
# Processing Record 13 of Set 6 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=touros
# Processing Record 14 of Set 6 | touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=port+keats
# Processing Record 15 of Set 6 | port keats
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=praya
# Processing Record 16 of Set 6 | praya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=meadow+lake
# Processing Record 17 of Set 6 | meadow lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=itanhaem
# Processing Record 18 of Set 6 | itanhaem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=paucartambo
# Processing Record 19 of Set 6 | paucartambo
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=sambava
# Processing Record 20 of Set 6 | sambava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=bilibino
# Processing Record 21 of Set 6 | bilibino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=umm+kaddadah
# Processing Record 22 of Set 6 | umm kaddadah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=cabedelo
# Processing Record 23 of Set 6 | cabedelo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=sebrovo
# Processing Record 24 of Set 6 | sebrovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=tsumeb
# Processing Record 25 of Set 6 | tsumeb
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=thompson
# Processing Record 26 of Set 6 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=rio+gallegos
# Processing Record 27 of Set 6 | rio gallegos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=abilene
# Processing Record 28 of Set 6 | abilene
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=peleduy
# Processing Record 29 of Set 6 | peleduy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=lahaina
# Processing Record 30 of Set 6 | lahaina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=atar
# Processing Record 31 of Set 6 | atar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=sindor
# Processing Record 32 of Set 6 | sindor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=grand+gaube
# Processing Record 33 of Set 6 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=pochutla
# Processing Record 34 of Set 6 | pochutla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=pomabamba
# Processing Record 35 of Set 6 | pomabamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=tigre
# Processing Record 36 of Set 6 | tigre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=svetlaya
# Processing Record 37 of Set 6 | svetlaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=yopal
# Processing Record 38 of Set 6 | yopal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=teguldet
# Processing Record 39 of Set 6 | teguldet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=katobu
# Processing Record 40 of Set 6 | katobu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=xinzhou
# Processing Record 41 of Set 6 | xinzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=nkwerre
# Processing Record 42 of Set 6 | nkwerre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=lazaro+cardenas
# Processing Record 43 of Set 6 | lazaro cardenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=bowen
# Processing Record 44 of Set 6 | bowen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=samusu
# Processing Record 45 of Set 6 | samusu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=allanmyo
# Processing Record 46 of Set 6 | allanmyo
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=ambilobe
# Processing Record 47 of Set 6 | ambilobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=nachingwea
# Processing Record 48 of Set 6 | nachingwea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=port+blair
# Processing Record 49 of Set 6 | port blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=greenville
# Processing Record 50 of Set 6 | greenville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=luderitz
# Processing Record 1 of Set 7 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=grindavik
# Processing Record 2 of Set 7 | grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=pyaozerskiy
# Processing Record 3 of Set 7 | pyaozerskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=prescott
# Processing Record 4 of Set 7 | prescott
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=ryotsu
# Processing Record 5 of Set 7 | ryotsu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=cienaga
# Processing Record 6 of Set 7 | cienaga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=eyl
# Processing Record 7 of Set 7 | eyl
# ...
# Processing Record 13 of Set 14 | karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=burica
# Processing Record 14 of Set 14 | burica
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=hirtshals
# Processing Record 15 of Set 14 | hirtshals
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=trang
# Processing Record 16 of Set 14 | trang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=yichang
# Processing Record 17 of Set 14 | yichang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=sokoni
# Processing Record 18 of Set 14 | sokoni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=yurimaguas
# Processing Record 19 of Set 14 | yurimaguas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=ribeira+brava
# Processing Record 20 of Set 14 | ribeira brava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=rio+cuarto
# Processing Record 21 of Set 14 | rio cuarto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=taltal
# Processing Record 22 of Set 14 | taltal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=leshan
# Processing Record 23 of Set 14 | leshan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=camargo
# Processing Record 24 of Set 14 | camargo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=otradinskiy
# Processing Record 25 of Set 14 | otradinskiy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=alghero
# Processing Record 26 of Set 14 | alghero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=prince+rupert
# Processing Record 27 of Set 14 | prince rupert
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=vila+velha
# Processing Record 28 of Set 14 | vila velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=rocha
# Processing Record 29 of Set 14 | rocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=kropotkin
# Processing Record 30 of Set 14 | kropotkin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=samfya
# Processing Record 31 of Set 14 | samfya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=grand+centre
# Processing Record 32 of Set 14 | grand centre
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=roald
# Processing Record 33 of Set 14 | roald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=mormugao
# Processing Record 34 of Set 14 | mormugao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=jumla
# Processing Record 35 of Set 14 | jumla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=mmabatho
# Processing Record 36 of Set 14 | mmabatho
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=shima
# Processing Record 37 of Set 14 | shima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=hereford
# Processing Record 38 of Set 14 | hereford
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=kokopo
# Processing Record 39 of Set 14 | kokopo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=darhan
# Processing Record 40 of Set 14 | darhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=muborak
# Processing Record 41 of Set 14 | muborak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=madang
# Processing Record 42 of Set 14 | madang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=arak
# Processing Record 43 of Set 14 | arak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=takoradi
# Processing Record 44 of Set 14 | takoradi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=alikalia
# Processing Record 45 of Set 14 | alikalia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=xining
# Processing Record 46 of Set 14 | xining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=paracuru
# Processing Record 47 of Set 14 | paracuru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=coxim
# Processing Record 48 of Set 14 | coxim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=narsaq
# Processing Record 49 of Set 14 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=kindia
# Processing Record 50 of Set 14 | kindia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=kikwit
# Processing Record 1 of Set 15 | kikwit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=carballo
# Processing Record 2 of Set 15 | carballo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=alofi
# Processing Record 3 of Set 15 | alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=fier
# Processing Record 4 of Set 15 | fier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=artyk
# Processing Record 5 of Set 15 | artyk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=mabaruma
# Processing Record 6 of Set 15 | mabaruma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=tura
# Processing Record 7 of Set 15 | tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=mutsamudu
# Processing Record 8 of Set 15 | mutsamudu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=iaciara
# Processing Record 9 of Set 15 | iaciara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=vilcun
# Processing Record 10 of Set 15 | vilcun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=bontang
# Processing Record 11 of Set 15 | bontang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=constitucion
# Processing Record 12 of Set 15 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=savinskiy
# Processing Record 13 of Set 15 | savinskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=razumnoye
# Processing Record 14 of Set 15 | razumnoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=tumannyy
# Processing Record 15 of Set 15 | tumannyy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=milingimbi
# Processing Record 16 of Set 15 | milingimbi
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=alotau
# Processing Record 17 of Set 15 | alotau
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=jacareacanga
# Processing Record 18 of Set 15 | jacareacanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=sentyabrskiy
# Processing Record 19 of Set 15 | sentyabrskiy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=moindou
# Processing Record 20 of Set 15 | moindou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=chunhuhub
# Processing Record 21 of Set 15 | chunhuhub
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=nivala
# Processing Record 22 of Set 15 | nivala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=lazurne
# Processing Record 23 of Set 15 | lazurne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=otane
# Processing Record 24 of Set 15 | otane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=kui+buri
# Processing Record 25 of Set 15 | kui buri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=burnie
# Processing Record 26 of Set 15 | burnie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=chara
# Processing Record 27 of Set 15 | chara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=matveyev+kurgan
# Processing Record 28 of Set 15 | matveyev kurgan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=saint-louis
# Processing Record 29 of Set 15 | saint-louis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=morondava
# Processing Record 30 of Set 15 | morondava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=tabiauea
# Processing Record 31 of Set 15 | tabiauea
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=hoquiam
# Processing Record 32 of Set 15 | hoquiam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=ishigaki
# Processing Record 33 of Set 15 | ishigaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=gushikawa
# Processing Record 34 of Set 15 | gushikawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=poronaysk
# Processing Record 35 of Set 15 | poronaysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=pandan
# Processing Record 36 of Set 15 | pandan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=mao
# Processing Record 37 of Set 15 | mao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=koutsouras
# Processing Record 38 of Set 15 | koutsouras
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=tollose
# Processing Record 39 of Set 15 | tollose
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=pangkalanbuun
# Processing Record 40 of Set 15 | pangkalanbuun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=boffa
# Processing Record 41 of Set 15 | boffa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=feicheng
# Processing Record 42 of Set 15 | feicheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=bolungarvik
# Processing Record 43 of Set 15 | bolungarvik
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=nawa
# Processing Record 44 of Set 15 | nawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=yenagoa
# Processing Record 45 of Set 15 | yenagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=wanaka
# Processing Record 46 of Set 15 | wanaka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=finschhafen
# Processing Record 47 of Set 15 | finschhafen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=micheweni
# Processing Record 48 of Set 15 | micheweni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=talara
# Processing Record 49 of Set 15 | talara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=lebedinyy
# Processing Record 50 of Set 15 | lebedinyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=taoudenni
# Processing Record 1 of Set 16 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=tarauaca
# Processing Record 2 of Set 16 | tarauaca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=cervo
# Processing Record 3 of Set 16 | cervo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=thinadhoo
# Processing Record 4 of Set 16 | thinadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=jiazi
# Processing Record 5 of Set 16 | jiazi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=watsa
# Processing Record 6 of Set 16 | watsa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=karla
# Processing Record 7 of Set 16 | karla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=lima
# Processing Record 8 of Set 16 | lima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=inderborskiy
# Processing Record 9 of Set 16 | inderborskiy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=ngunguru
# Processing Record 10 of Set 16 | ngunguru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=chlorakas
# Processing Record 11 of Set 16 | chlorakas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=gallup
# Processing Record 12 of Set 16 | gallup
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=manokwari
# Processing Record 13 of Set 16 | manokwari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7ff403200ab6145d3262ed8048eedfb&q=chernyshevskiy
# Processing Record 14 of Set 16 | chernyshevskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0             Salta      AR -24.7859  -65.4117     56.57        81
# 1          Cherskiy      RU  68.7500  161.3000     27.27        81
# 2            Namibe      AO -15.1961   12.1522     72.41        66
# 3           Rikitea      PF -23.1203 -134.9692     76.87        70
# 4            Barrow      US  71.2906 -156.7887     24.82        74
# ..              ...     ...      ...       ...       ...       ...
# 696        Ngunguru      NZ -35.6167  174.5000     59.05        60
# 697       Chlorakas      CY  34.8042   32.4083     56.28        77
# 698          Gallup      US  35.5281 -108.7426     69.64        12
# 699       Manokwari      ID  -0.8667  134.0833     83.86        64
# 700  Chernyshevskiy      RU  63.0128  112.4714     41.00        76
#
#      Cloudiness  Wind Speed  City_Description
# 0             0        3.00         clear sky
# 1           100        6.60   overcast clouds
# 2            83        8.77     broken clouds
# 3            10       14.94         clear sky
# 4           100       12.66   overcast clouds
# ..          ...         ...               ...
# 696           0       14.34         clear sky
# 697          20        8.05        few clouds
# 698           0       14.97         clear sky
# 699          43        3.80  scattered clouds
# 700          29        9.28  scattered clouds
#
# [701 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
